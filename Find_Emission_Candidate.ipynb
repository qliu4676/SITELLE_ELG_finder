# %%
from pipeline import *
from utils import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # A2390C

# %%
# %run Find_Emission_Candidate.py "/home/qliu/data/A2390C4new.fits" --NAME 'A2390C' -z 0.228 -m 'MMA' -v --OUT_DIR './output' --DEEP_FRAME "/home/qliu/data/A2390C_deep.fits"
# Out:
# Read raw SITELLE datacube:  /home/qliu/data/A2390C4new.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...

# %%
# %run Find_Emission_Candidate.py "/home/qliu/data/A2390C4new" -n 'A2390C' -z 0.228 -m 'MMA' -v --skip 'raw,spec,temp,cc' --OUT_DIR './output' --DEEP_FRAME "/home/qliu/data/A2390C_deep.fits"
# Out:
# Skip processing raw datacube.
# Skip extraction of spectra.
# Skip building template.
# Skip cross-correlation.
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read Emission Line Template:
# ['./output/template/Template-A2390C_Ha-NII_gauss.fits',
#  './output/template/Template-A2390C_Hb-OIII_gauss.fits',
#  './output/template/Template-A2390C_OII_gauss.fits']
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# Match with SDSS DR12 stars...
# Measuring Equivalent Width for lines...
#
# Separate candidates into three subsamples based on S/N.
# A: 63 candidates:
#  [   1  212  234  244  349  398  417  451  458  462  489  491  557  718
#   728  828  832  863  868 1004 1085 1117 1130 1216 1234 1320 1337 1378
#  1394 1465 1472 1477 1496 1508 1524 1543 1557 1562 1563 1586 1607 1610
#  1618 1624 1658 1687 1711 1803 1840 1843 1867 1875 1877 1878 1887 1911
# ...

# %%
# %run -i Find_Emission_Candidate.py "/home/qliu/data/A2390C4new" -n 'A2390C' -w --OUT_DIR './output/'
# Out:
# Skip processing raw datacube.
# Skip extraction of spectra.
# Skip building template.
# Skip cross-correlation.
# Skip ploting ELG candidate.
# Save candidate list as : ./output/A2390C/A2390C_ELG_list.txt

# %% [markdown]
# #### LPF with a larger kernel.

# %%
# %run Find_Emission_Candidate.py "/home/qliu/data/A2390C4new.fits" --NAME 'A2390C' -z 0.228 -m 'MMA' -v -K [15,5] --OUT_DIR './output2' --DEEP_FRAME "/home/qliu/data/A2390C_deep.fits"
# Out:
# [15  5]
# ./output2/A2390C does not exist. Make a new directory.
# Read raw SITELLE datacube:  /home/qliu/data/A2390C4new.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...

# %% [markdown]
# # A2390E

# %%
# %run -i Find_Emission_Candidate.py "/home/qliu/data/A2390F/A2390SEC4.fits" --NAME 'A2390E' -z 0.228 -m 'MMA' -v --OUT_DIR './output' --DEEP_FRAME "/home/qliu/data/A2390F/A2390SE_C4.merged.InterferogramMerger.deep_frame.fits"
# Out:
# Read raw SITELLE datacube:  /home/qliu/data/A2390F/A2390SEC4.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...

# %%
# %run -i Find_Emission_Candidate.py ' ' -n 'A2390E' -w --OUT_DIR './output'
# Out:
# Skip processing raw datacube.
# Skip extraction of spectra.
# Skip building template.
# Skip cross-correlation.
# Skip ploting ELG candidate.
# Save candidate list as : ./output/A2390E/A2390E_ELG_list.txt

# %% [markdown]
# #### LPF with a larger kernel.

# %%
# %run -i Find_Emission_Candidate.py "/home/qliu/data/A2390F/A2390SEC4.fits" --NAME 'A2390E' -z 0.228 -K [15,5] -m 'MMA' -v --OUT_DIR './output2' --DEEP_FRAME "/home/qliu/data/A2390F/A2390SE_C4.merged.InterferogramMerger.deep_frame.fits"
# Out:
# [15  5]
# Read raw SITELLE datacube:  /home/qliu/data/A2390F/A2390SEC4.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...

# %% [markdown]
# # A2390W

# %%
# %run -i Find_Emission_Candidate.py "/home/qliu/data/A2390F/A2390NWC4.fits" --NAME 'A2390W' -z 0.228 -m 'MMA' -v --OUT_DIR './output' --DEEP_FRAME "/home/qliu/data/A2390F/A2390NW_C4.merged.InterferogramMerger.deep_frame.fits"
# Out:
# Read raw SITELLE datacube:  /home/qliu/data/A2390F/A2390NWC4.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...

# %%
# %run -i Find_Emission_Candidate.py ' ' -n 'A2390W' -w --OUT_DIR './output'
# Out:
# Skip processing raw datacube.
# Skip extraction of spectra.
# Skip building template.
# Skip cross-correlation.
# Skip ploting ELG candidate.
# Save candidate list as : ./output/A2390W/A2390W_ELG_list.txt

# %% [markdown]
# #### LPF with a larger kernel.

# %%
# %run -i Find_Emission_Candidate.py "/home/qliu/data/A2390F/A2390NWC4.fits" --NAME 'A2390W' -z 0.228 -K [15,5] -m 'MMA' -v --OUT_DIR './output2' --DEEP_FRAME "/home/qliu/data/A2390F/A2390NW_C4.merged.InterferogramMerger.deep_frame.fits"
# Out:
# [15  5]
# Read raw SITELLE datacube:  /home/qliu/data/A2390F/A2390NWC4.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...

# %% [markdown]
# # A2465C

# %%
# %run -i Find_Emission_Candidate.py "/home/qliu/data/A2465/5PrUCR/2345354p.fits" --NAME 'A2465C' -z 0.245 -m 'MMA' -v --OUT_DIR './output' --DEEP_FRAME "/home/qliu/data/A2465/5PrUCR/2345354v.fits"
# Out:
# ./output/A2465C does not exist. Make a new directory.
# Read raw SITELLE datacube:  /home/qliu/data/A2465/5PrUCR/2345354p.fits
# INFO:
#                 Inconsistent SIP distortion information is present in the FITS header and the WCS object:
#                 SIP coefficients were detected, but CTYPE is missing a "-SIP" suffix.
#                 astropy.wcs is using the SIP distortion coefficients,
#                 therefore the coordinates calculated here might be incorrect.
#
#                 If you do not want to apply the SIP distortion coefficients,
#                 please remove the SIP coefficients from the FITS header or the
#                 WCS object.  As an example, if the image is already distortion-corrected
#                 (e.g., drizzled) then distortion components should not apply and the SIP
#                 coefficients should be removed.
#
#                 While the SIP distortion coefficients are being applied here, if that was indeed the intent,
# ...
