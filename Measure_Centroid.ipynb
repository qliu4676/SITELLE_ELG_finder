# %%
from pipeline import *
from utils import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # A2390C

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.0 --SUM_TYPE 'mean' --SUB_CONT --LPF
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.5 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   239.035        344.343      1342.154
#   6C 328.3969 17.5803 0.2472 ...       nan            nan           nan
#  89C 328.3088 17.5895 0.2475 ...       nan            nan           nan
#  96C 328.3757 17.5897  0.226 ...       nan            nan           nan
# 106C 328.4743 17.5928 0.2322 ...       nan            nan           nan
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_mean_sn2.5_contsub_lpf_NB.txt

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.0 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   268.267        344.343      1342.154
#   6C 328.3969 17.5803 0.2472 ...       nan            nan           nan
#  89C 328.3088 17.5895 0.2475 ...       nan            nan           nan
#  96C 328.3757 17.5897  0.226 ...       nan            nan           nan
# 106C 328.4743 17.5928 0.2322 ...       nan            nan           nan
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_mean_sn2.0_contsub_lpf_NB.txt

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   263.171        344.343      1342.156
#   6C 328.3969 17.5803 0.2472 ...    11.461          3.134      1289.473
#  89C 328.3088 17.5895 0.2475 ...   136.864         40.412      1556.574
#  96C 328.3757 17.5897  0.226 ...     270.0          14.08      1218.602
# 106C 328.4743 17.5928 0.2322 ...   170.375        326.698       1373.08
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_mean_sn2.0_lpf_NB.txt

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.5 --SUM_TYPE 'mean' --LPF --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   237.404        344.343      1342.156
#   6C 328.3969 17.5803 0.2472 ...    10.415          3.134      1289.473
#  89C 328.3088 17.5895 0.2475 ...   119.094         40.412      1556.574
#  96C 328.3757 17.5897  0.226 ...     270.0          14.08      1218.602
# 106C 328.4743 17.5928 0.2322 ...    137.16        326.698       1373.08
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_mean_sn2.5_lpf_NB.txt

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.0 --SUM_TYPE 'weighted' --LPF --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   262.737        344.343      1342.156
#   6C 328.3969 17.5803 0.2472 ...    10.165          3.134      1289.473
#  89C 328.3088 17.5895 0.2475 ...   136.864         40.412      1556.574
#  96C 328.3757 17.5897  0.226 ...     270.0          14.08      1218.602
# 106C 328.4743 17.5928 0.2322 ...   170.375        326.698       1373.08
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_weighted_sn2.0_lpf_NB.txt

# %%
# A2390C keep cont
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.5 --SUM_TYPE 'weighted' --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: weighted
# Continuum Subtracted?: False
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   236.388        344.343      1342.156
#   6C 328.3969 17.5803 0.2472 ...   345.377          3.134      1289.473
#  89C 328.3088 17.5895 0.2475 ...     270.0         40.412      1556.574
#  96C 328.3757 17.5897  0.226 ...     270.0          14.08      1218.602
# 106C 328.4743 17.5928 0.2322 ...    137.16        326.698       1373.08
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_weighted_sn2.5_lpf_NB.txt

# %%
# A2390C
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   263.171        344.343      1342.156
#   6C 328.3969 17.5803 0.2472 ...    11.461          3.134      1289.473
#  89C 328.3088 17.5895 0.2475 ...   136.864         40.412      1556.574
#  96C 328.3757 17.5897  0.226 ...     270.0          14.08      1218.602
# 106C 328.4743 17.5928 0.2322 ...   170.375        326.698       1373.08
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_mean_sn2.0_lpf_NB.txt

# %%
# A2390C
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.0 --SUM_TYPE 'weighted' --SUB_CONT --LPF
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...

# %%
# A2390C
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.5 --SUM_TYPE 'mean' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   237.404        344.343      1342.156
#   6C 328.3969 17.5803 0.2472 ...    10.415          3.134      1289.473
#  89C 328.3088 17.5895 0.2475 ...   119.094         40.412      1556.574
#  96C 328.3757 17.5897  0.226 ...     270.0          14.08      1218.602
# 106C 328.4743 17.5928 0.2322 ...    137.16        326.698       1373.08
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_mean_sn2.5_lpf_NB.txt

# %%
# A2390C
# %run -i Measure_Centroid.py 'A2390C' --SN_THRE 2.5 --SUM_TYPE 'weighted' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390C from : ./output/A2390C/A2390C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#   1C 328.4375 17.5798 0.2502 ...   236.388        344.343      1342.156
#   6C 328.3969 17.5803 0.2472 ...   345.377          3.134      1289.473
#  89C 328.3088 17.5895 0.2475 ...     270.0         40.412      1556.574
#  96C 328.3757 17.5897  0.226 ...     270.0          14.08      1218.602
# 106C 328.4743 17.5928 0.2322 ...    137.16        326.698       1373.08
# Save centroid measurement as catalog:  ./output/A2390C/centroid_analysis_A2390C_weighted_sn2.5_lpf_NB.txt

# %% [markdown]
# # A2390W

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.0 --SUM_TYPE 'mean' --SUB_CONT --LPF
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.5 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   183.591        131.521       724.209
#  41W 328.3371 17.7382 0.2422 ...       nan            nan           nan
#  73W 328.3547 17.7419 0.2271 ...       nan            nan           nan
#  90W 328.3716 17.7438 0.2479 ...       nan            nan           nan
# 111W 328.3619 17.7453 0.2215 ...   139.399        141.521       712.593
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_mean_sn2.5_contsub_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.0 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   196.005        131.521       724.209
#  41W 328.3371 17.7382 0.2422 ...       nan            nan           nan
#  73W 328.3547 17.7419 0.2271 ...    352.95        134.991       734.597
#  90W 328.3716 17.7438 0.2479 ...       nan            nan           nan
# 111W 328.3619 17.7453 0.2215 ...    102.28        141.521       712.593
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_mean_sn2.0_contsub_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   210.616        131.521       724.208
#  41W 328.3371 17.7382 0.2422 ...   193.666        124.049       854.235
#  73W 328.3547 17.7419 0.2271 ...   355.064         134.99       734.596
#  90W 328.3716 17.7438 0.2479 ...     270.0        147.828       638.803
# 111W 328.3619 17.7453 0.2215 ...   104.981        141.521       712.592
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_mean_sn2.0_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.5 --SUM_TYPE 'mean' --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: mean
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   181.367        131.521       724.208
#  41W 328.3371 17.7382 0.2422 ...    152.67        124.049       854.235
#  73W 328.3547 17.7419 0.2271 ...       nan         134.99       734.596
#  90W 328.3716 17.7438 0.2479 ...     270.0        147.828       638.803
# 111W 328.3619 17.7453 0.2215 ...    152.25        141.521       712.592
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_mean_sn2.5_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.0 --SUM_TYPE 'weighted' --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: weighted
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   217.354        131.521       724.208
#  41W 328.3371 17.7382 0.2422 ...   150.232        124.049       854.235
#  73W 328.3547 17.7419 0.2271 ...    355.87         134.99       734.596
#  90W 328.3716 17.7438 0.2479 ...     270.0        147.828       638.803
# 111W 328.3619 17.7453 0.2215 ...   178.739        141.521       712.592
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_weighted_sn2.0_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.5 --SUM_TYPE 'weighted' --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: weighted
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   184.395        131.521       724.208
#  41W 328.3371 17.7382 0.2422 ...   173.033        124.049       854.235
#  73W 328.3547 17.7419 0.2271 ...       nan         134.99       734.596
#  90W 328.3716 17.7438 0.2479 ...     270.0        147.828       638.803
# 111W 328.3619 17.7453 0.2215 ...   154.827        141.521       712.592
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_weighted_sn2.5_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.5 --SUM_TYPE 'mean' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   181.367        131.521       724.208
#  41W 328.3371 17.7382 0.2422 ...    152.67        124.049       854.235
#  73W 328.3547 17.7419 0.2271 ...       nan         134.99       734.596
#  90W 328.3716 17.7438 0.2479 ...     270.0        147.828       638.803
# 111W 328.3619 17.7453 0.2215 ...    152.25        141.521       712.592
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_mean_sn2.5_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   210.616        131.521       724.208
#  41W 328.3371 17.7382 0.2422 ...   193.666        124.049       854.235
#  73W 328.3547 17.7419 0.2271 ...   355.064         134.99       734.596
#  90W 328.3716 17.7438 0.2479 ...     270.0        147.828       638.803
# 111W 328.3619 17.7453 0.2215 ...   104.981        141.521       712.592
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_mean_sn2.0_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.5 --SUM_TYPE 'weighted' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID     ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# ---- -------- ------- ------ ... --------- -------------- -------------
#  30W 328.3526 17.7384 0.2274 ...   184.395        131.521       724.208
#  41W 328.3371 17.7382 0.2422 ...   173.033        124.049       854.235
#  73W 328.3547 17.7419 0.2271 ...       nan         134.99       734.596
#  90W 328.3716 17.7438 0.2479 ...     270.0        147.828       638.803
# 111W 328.3619 17.7453 0.2215 ...   154.827        141.521       712.592
# Save centroid measurement as catalog:  ./output/A2390W/centroid_analysis_A2390W_weighted_sn2.5_lpf_NB.txt

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' --SN_THRE 2.0 --SUM_TYPE 'weighted' --LPF --SUB_CONT
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...

# %% [markdown]
# # A2390E

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.5 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   241.189        327.885      3242.976
# 25E 328.4222 17.4499 0.2212 ...   218.702        355.854      2752.799
# 37E 328.5047 17.4507 0.2329 ...       nan            nan           nan
# 46E 328.4819 17.4516 0.2303 ...       nan            nan           nan
# 78E 328.4359 17.4558 0.2291 ...   198.786         352.66      2701.043
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_mean_sn2.5_contsub_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.0 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   250.688        327.885      3242.976
# 25E 328.4222 17.4499 0.2212 ...    202.81        355.854      2752.799
# 37E 328.5047 17.4507 0.2329 ...       nan            nan           nan
# 46E 328.4819 17.4516 0.2303 ...       nan            nan           nan
# 78E 328.4359 17.4558 0.2291 ...   225.733         352.66      2701.043
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_mean_sn2.0_contsub_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.584s
# Measure Centroid...

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   250.688        327.885      3242.977
# 25E 328.4222 17.4499 0.2212 ...   204.444        355.854      2752.801
# 37E 328.5047 17.4507 0.2329 ...     315.0        338.502        2941.1
# 46E 328.4819 17.4516 0.2303 ...     77.79        342.981      2851.669
# 78E 328.4359 17.4558 0.2291 ...   221.039         352.66      2701.044
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_mean_sn2.0_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.5 --SUM_TYPE 'mean' --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: mean
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   251.259        327.885      3242.977
# 25E 328.4222 17.4499 0.2212 ...   200.768        355.854      2752.801
# 37E 328.5047 17.4507 0.2329 ...     270.0        338.502        2941.1
# 46E 328.4819 17.4516 0.2303 ...     270.0        342.981      2851.669
# 78E 328.4359 17.4558 0.2291 ...   212.397         352.66      2701.044
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_mean_sn2.5_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.0 --SUM_TYPE 'weighted' --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: weighted
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   256.142        327.885      3242.977
# 25E 328.4222 17.4499 0.2212 ...   271.281        355.854      2752.801
# 37E 328.5047 17.4507 0.2329 ...     315.0        338.502        2941.1
# 46E 328.4819 17.4516 0.2303 ...    85.497        342.981      2851.669
# 78E 328.4359 17.4558 0.2291 ...   183.983         352.66      2701.044
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_weighted_sn2.0_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.5 --SUM_TYPE 'weighted' --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: weighted
# Continuum Subtracted?: False
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   253.194        327.885      3242.977
# 25E 328.4222 17.4499 0.2212 ...   236.684        355.854      2752.801
# 37E 328.5047 17.4507 0.2329 ...     270.0        338.502        2941.1
# 46E 328.4819 17.4516 0.2303 ...     270.0        342.981      2851.669
# 78E 328.4359 17.4558 0.2291 ...   224.046         352.66      2701.044
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_weighted_sn2.5_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.5 --SUM_TYPE 'mean' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   251.259        327.885      3242.977
# 25E 328.4222 17.4499 0.2212 ...   200.768        355.854      2752.801
# 37E 328.5047 17.4507 0.2329 ...     270.0        338.502        2941.1
# 46E 328.4819 17.4516 0.2303 ...     270.0        342.981      2851.669
# 78E 328.4359 17.4558 0.2291 ...   212.397         352.66      2701.044
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_mean_sn2.5_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.0 --SUM_TYPE 'mean' --LPF --SUB_CONT --SAVE
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 13E 328.5654 17.4498 0.2338 ...   250.688        327.885      3242.977
# 25E 328.4222 17.4499 0.2212 ...   204.444        355.854      2752.801
# 37E 328.5047 17.4507 0.2329 ...     315.0        338.502        2941.1
# 46E 328.4819 17.4516 0.2303 ...     77.79        342.981      2851.669
# 78E 328.4359 17.4558 0.2291 ...   221.039         352.66      2701.044
# Save centroid measurement as catalog:  ./output/A2390E/centroid_analysis_A2390E_mean_sn2.0_lpf_NB.txt

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.5 --SUM_TYPE 'weighted' --LPF --SUB_CONT
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' --SN_THRE 2.0 --SUM_TYPE 'weighted' --LPF --SUB_CONT
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...

# %% [markdown]
# # A2465C

# %%
# A2465C keep cont
# %run -i Measure_Centroid.py 'A2465C' -z 0.245 --SN_THRE 2.5 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.5
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2465C from : ./output/A2465C/A2465C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG1 coordinate:  22h39m40.4832s -05d43m26.3388s
# BCG2 coordinate:  22h39m24.5453s -05d47m17.6388s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 32C  339.975 -5.8422  0.245 ...       nan            nan           nan
# 33C 339.8778 -5.8445 0.2448 ...   142.074        335.702       689.878
# 64C  339.952 -5.8401  0.236 ...       nan            nan           nan
# 70C 339.8083 -5.8396 0.2465 ...    83.967         40.441       754.825
# 74C 339.8108 -5.8391 0.2452 ...       nan            nan           nan
# ...

# %%
# A2465C keep cont
# %run -i Measure_Centroid.py 'A2465C' -z 0.245 --SN_THRE 2.0 --SUM_TYPE 'mean' --SUB_CONT --LPF --SAVE
# Out:
# S/N = 2.0
# Emission: mean
# Continuum Subtracted?: True
# Use LPF cube?: True
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2465C from : ./output/A2465C/A2465C-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG1 coordinate:  22h39m40.4832s -05d43m26.3388s
# BCG2 coordinate:  22h39m24.5453s -05d47m17.6388s
# Measure Centroid...
#  ID    ra      dec     z    ... pa_ISO-Dm clus_cen_angle dist_clus_cen
# --- -------- ------- ------ ... --------- -------------- -------------
# 32C  339.975 -5.8422  0.245 ...       nan            nan           nan
# 33C 339.8778 -5.8445 0.2448 ...    80.838        335.702       689.878
# 64C  339.952 -5.8401  0.236 ...       nan            nan           nan
# 70C 339.8083 -5.8396 0.2465 ...   100.947         40.441       754.825
# 74C 339.8108 -5.8391 0.2452 ...       nan            nan           nan
# ...

# %% [markdown]
# ## Old Measurement

# %%
# A2390E
# %run -i Measure_Centroid.py 'A2390E' 2.0 'mean'
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390E from : ./output/A2390E/A2390E-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
# /home/qliu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/qliu/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# ...

# %%
# A2390W
# %run -i Measure_Centroid.py 'A2390W' 2.0 'mean'
# Out:
# Use LPF cube
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# Measure Centroid...
# /home/qliu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/qliu/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# ...

# %%
datacube.centroid_analysis(1884, centroid_type="ISO-D", morph_cen=True)
# Out:
# stddev emission: 0.012 / continuum: 0.004
# Centroid EM: (1317.03+/-0.11, 1535.10+/-0.11)
# Centroid CON: (1319.25+/-0.09, 1535.10+/-0.09)
# {'diff_angle': 147.83156774338966,
#  'cen_offset': 2.2139179772334288,
#  'diff_angle_std': 3.6012607256495754,
#  'cen_offset_std': 0.1391532836969231,
#  'pa': 269.83766278456557,
#  'clus_cen_angle': 122.00609504117591,
#  'dist_clus_cen': 408.786356205759}

# %%
# Arugument
name = 'A2390W'
sn_thre = 2.0
sum_type = 'weighted'

z0 = 0.228
mode = "MMA"
wavl_mask = [[7950,8006], [8020,8040], [8230,8280]]

output_dir = './output'
save_path = os.path.join(output_dir, name)
centroid_path = os.path.join(output_dir, 'centroid', name)

cube_path = os.path.join(save_path, '%s_cube.fits'%name)
cube_lpf_path = os.path.join(save_path, '%s_cube_lpf.fits'%name)
    
table_path = os.path.join(save_path, '%s_%s_lpf.dat'%(name, mode))
seg_path = os.path.join(save_path, '%s_segm_%s_lpf.fits'%(name, mode))
deep_path = os.path.join(save_path, '%s_DF.fits'%(name))
mask_edge_path = os.path.join(save_path, 'Raw_stack_%s_mask.fits'%name)
spec_path = os.path.join(save_path, '%s-spec-%s_lpf.fits'%(name, mode))
template_path = os.path.join(output_dir, 'template')
CC_res_path = os.path.join(save_path, '%s-cc-%s_lpf.pkl'%(name, mode))
candidate_path = os.path.join(save_path, 'pic/candidate_%s_lpf'%mode)

# Read
datacube = Read_Datacube(cube_path, name, z0, 
                         mode=mode, wavl_mask=wavl_mask,
                         table=table_path, seg_map=seg_path,
                         deep_frame=deep_path,
                         mask_edge=mask_edge_path)
                         
datacube.get_wcs()
cube_detect_path = os.path.join(save_path, '%s_cube_lpf.fits'%name)
datacube.src_map = fits.getdata(cube_detect_path)
datacube.read_spec(spec_path)
datacube.read_template(template_path, n_intp=2, name=name, verbose=False)
datacube.read_cc_result(CC_res_path)

# BCG
datacube.assign_BCG_coordinate((328.40351201,17.69544013))
X_BCG, Y_BCG = datacube.wcs.all_world2pix(datacube.coord_BCG.ra, datacube.coord_BCG.dec, 0)
datacube.pos_BCG = (X_BCG, Y_BCG)

# Read
datacube_lpf = Read_Datacube(cube_lpf_path, name, z0, 
                             mode=mode, wavl_mask=wavl_mask,
                             table=table_path, seg_map=seg_path,
                             deep_frame=deep_path,
                             mask_edge=mask_edge_path)
                         
datacube_lpf.get_wcs()
datacube_lpf.read_spec(spec_path)
datacube_lpf.read_template(template_path, n_intp=2, name=name, verbose=False)
datacube_lpf.read_cc_result(CC_res_path)

# BCG
datacube_lpf.assign_BCG_coordinate((328.40351201,17.69544013))
X_BCG, Y_BCG = datacube_lpf.wcs.all_world2pix(datacube.coord_BCG.ra, datacube.coord_BCG.dec, 0)
datacube_lpf.pos_BCG = (X_BCG, Y_BCG)

# Candidate
candidate_path_V = os.path.join(candidate_path,"V/%s#*.png"%name)
dir_V = glob.glob(candidate_path_V)
Num_V = np.sort(np.array([re.compile(r'\d+').findall(el)[-1] for el in dir_V]).astype("int"))
# Out:
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s
# [[7950, 8006], [8020, 8040], [8230, 8280]]  will be flagged.
# Read cross-correlation results for A2390W from : ./output/A2390W/A2390W-cc-MMA_lpf.pkl
# Template used: ['Ha-NII_gauss', 'Hb-OIII_gauss', 'OII_gauss']
# BCG coordinate:  21h53m36.8429s +17d41m43.5845s

# %%
res=datacube.centroid_analysis(1217, sum_type='weighted', centroid_type="ISO-D", morph_cen=False)
print(res['diff_angle'], res['cen_offset'])
res_lpf=datacube_lpf.centroid_analysis(1217, sum_type='weighted', centroid_type="ISO-D", morph_cen=False)
print(res_lpf['diff_angle'], res_lpf['cen_offset'])
# Out:
# stddev emission: 0.023 / continuum: 0.004
# Centroid EM: (1122.90+/-0.01, 1441.28+/-0.02)
# Centroid CON: (1122.58+/-0.01, 1441.35+/-0.01)
# 53.27595466198167 0.32812231116779816
# stddev emission: 0.023 / continuum: 0.003
# Centroid EM: (1122.92+/-0.01, 1441.27+/-0.02)
# Centroid CON: (1122.63+/-0.01, 1441.32+/-0.01)
# 50.40513115613592 0.2920566228176621

# %%
num=1395
res=datacube.centroid_analysis(num, sum_type='weighted', centroid_type="ISO-D", morph_cen=False)
print(res['diff_angle'], res['cen_offset'])
res_lpf=datacube_lpf.centroid_analysis(num, sum_type='weighted', centroid_type="ISO-D", morph_cen=False)
print(res_lpf['diff_angle'], res_lpf['cen_offset'])
# Out:
# stddev emission: 0.018 / continuum: 0.004
# Centroid EM: (1501.89+/-0.02, 292.77+/-0.02)
# Centroid CON: (1502.66+/-0.01, 292.27+/-0.01)
# 125.35408238362626 0.9166854689530364
# stddev emission: 0.016 / continuum: 0.004
# Centroid EM: (1501.88+/-0.01, 292.75+/-0.02)
# Centroid CON: (1502.67+/-0.01, 291.98+/-0.01)
# 113.99385132670966 1.1100530828606545

# %%
num=366
res=datacube.centroid_analysis(num, sum_type='mean', centroid_type="ISO-D", morph_cen=False)
print(res['diff_angle'], res['cen_offset'])
res_lpf=datacube_lpf.centroid_analysis(num, sum_type='mean', centroid_type="ISO-D", morph_cen=False)
print(res_lpf['diff_angle'], res_lpf['cen_offset'])
# Out:
# stddev emission: 0.019 / continuum: 0.004
# Centroid EM: (457.08+/-0.03, 527.50+/-0.02)
# Centroid CON: (456.79+/-0.01, 527.30+/-0.01)
# 18.41812070833174 0.3544629527800818
# stddev emission: 0.019 / continuum: 0.004
# Centroid EM: (457.10+/-0.03, 527.54+/-0.02)
# Centroid CON: (456.73+/-0.01, 527.19+/-0.00)
# 9.618693247037271 0.5123212656936806

# %%
num=366
res=datacube.centroid_analysis(num, sum_type='mean', centroid_type="ISO-D", morph_cen=False)
print(res['diff_angle'], res['cen_offset'])
res_lpf=datacube_lpf.centroid_analysis(num, sum_type='mean', centroid_type="ISO-D", morph_cen=False)
print(res_lpf['diff_angle'], res_lpf['cen_offset'])
# Out:
# stddev emission: 0.007 / continuum: 0.004
# Centroid EM: (455.59+/-0.03, 527.00+/-0.05)
# Centroid CON: (456.73+/-0.01, 527.33+/-0.01)
# 143.2116326302572 1.1917607742340186
# stddev emission: 0.007 / continuum: 0.004
# Centroid EM: (455.61+/-0.03, 527.00+/-0.05)
# Centroid CON: (456.69+/-0.01, 527.22+/-0.00)
# 138.34886326867007 1.1043718068079629
